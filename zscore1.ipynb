# %% [markdown]
# <a href="https://colab.research.google.com/github/veequal/data-science-week1/blob/main/zscore1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Source - http://stackoverflow.com/a
# Posted by tanemaki, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0

import pandas as pd
import numpy as np
from scipy import stats

df = pd.DataFrame(np.random.randn(100, 3))

df[(np.abs(stats.zscore(df)) < 3).all(axis=1)] # Many standard deviations a data point is from the mean of its dataset.Z-score

print(df)
# Out:
#            0         1         2
# 0   0.100371 -0.445925 -0.656085
# 1  -1.193806 -0.374751 -0.400575
# 2  -0.785914  1.411454 -0.558117
# 3   0.593127 -0.505922  0.391345
# 4   0.389297  0.407743 -1.623963
# ..       ...       ...       ...
# 95 -0.210986 -0.411775  1.394732
# 96 -2.678311  0.222587  0.080992
# 97  1.378744 -0.231947  0.647230
# 98 -0.686712 -0.552329 -0.244604
# 99 -0.322758  0.176446 -0.457219
#
# [100 rows x 3 columns]

# %%
# Step 1: Create a simple dataframe with obvious outliers
data = {
    'Score': [85, 90, 78, 92, 88, 200, 85, 89, -50, 87]
}
df = pd.DataFrame(data)

print("ORIGINAL DATA: ")
print(df)

# Step 2: Romove outliers using Z-score method
df_clean = df[(np.abs(stats.zscore(df)) < 2).all(axis=1)]

print("\nCLEANED DATA (outliers removed): ")
print(df_clean)

# Step 3: Show what happened
print(f"\nSUMMARY: ")
print(f"Original rows: {len(df)}")
print(f"Rows after cleaning: {len(df_clean)}")
print(f"Outliers removed: {len(df) - len(df_clean)}")
# Out:
# ORIGINAL DATA:
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 5    200
# 6     85
# 7     89
# 8    -50
# 9     87
#
# CLEANED DATA (outliers removed):
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 6     85
# 7     89
# 9     87
#
# SUMMARY:
# Original rows: 10
# Rows after cleaning: 8
# Outliers removed: 2
